# %%
import sys
import gym
import torch
import pylab
import random
import numpy as np
from collections import deque
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import transforms
from prioritized_memory import Memory

# %%
EPISODES = 500

# approximate Q function using Neural Network
# state is input and Q Value of each action is output of network
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(state_size, 24),
            nn.ReLU(),
            nn.Linear(24, 24),
            nn.ReLU(),
            nn.Linear(24, action_size)
        )

    def forward(self, x):
        return self.fc(x)

# %%
# DQN Agent for the Cartpole
# it uses Neural Network to approximate q function
# and prioritized experience replay memory & target q network
class DQNAgent():
    def __init__(self, state_size, action_size):
        # if you want to see Cartpole learning, then change to True
        self.render = False
        self.load_model = False

        # get size of state and action
        self.state_size = state_size
        self.action_size = action_size

        # These are hyper parameters for the DQN
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.memory_size = 20000
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.explore_step = 5000
        self.epsilon_decay = (self.epsilon - self.epsilon_min) / self.explore_step
        self.batch_size = 64
        self.train_start = 1000

        # create prioritized replay memory using SumTree
        self.memory = Memory(self.memory_size)

        # create main model and target model
        self.model = DQN(state_size, action_size)
        self.model.apply(self.weights_init)
        self.target_model = DQN(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(),
                                    lr=self.learning_rate)

        # initialize target model
        self.update_target_model()

        if self.load_model:
            self.model = torch.load('save_model/cartpole_dqn')

    # weight xavier initialize
    def weights_init(self, m):
        classname = m.__class__.__name__
        if classname.find('Linear') != -1:
            torch.nn.init.xavier_uniform(m.weight)

    # after some time interval update the target model to be same with model
    def update_target_model(self):
        self.target_model.load_state_dict(self.model.state_dict())

    # get action from model using epsilon-greedy policy
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            state = torch.from_numpy(state)
            state = Variable(state).float().cpu()
            q_value = self.model(state)
            _, action = torch.max(q_value, 1)
            return int(action)

    # save sample (error,<s,a,r,s'>) to the replay memory
    def append_sample(self, state, action, reward, next_state, done):
        target = self.model(Variable(torch.FloatTensor(state))).data
        old_val = target[0][action]
        target_val = self.target_model(Variable(torch.FloatTensor(next_state))).data
        if done:
            target[0][action] = reward
        else:
            target[0][action] = reward + self.discount_factor * torch.max(target_val)

        error = abs(old_val - target[0][action])

        self.memory.add(error, (state, action, reward, next_state, done))

    # pick samples from prioritized replay memory (with batch_size)
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon -= self.epsilon_decay

        mini_batch, idxs, is_weights = self.memory.sample(self.batch_size)
        mini_batch = np.array(mini_batch).transpose()

        states = np.vstack(mini_batch[0])
        actions = list(mini_batch[1])
        rewards = list(mini_batch[2])
        next_states = np.vstack(mini_batch[3])
        dones = mini_batch[4]

        # bool to binary
        dones = dones.astype(int)

        # Q function of current state
        states = torch.Tensor(states)
        states = Variable(states).float()
        pred = self.model(states)

        # one-hot encoding
        a = torch.LongTensor(actions).view(-1, 1)

        one_hot_action = torch.FloatTensor(self.batch_size, self.action_size).zero_()
        one_hot_action.scatter_(1, a, 1)

        pred = torch.sum(pred.mul(Variable(one_hot_action)), dim=1)

        # Q function of next state
        next_states = torch.Tensor(next_states)
        next_states = Variable(next_states).float()
        next_pred = self.target_model(next_states).data

        rewards = torch.FloatTensor(rewards)
        dones = torch.FloatTensor(dones)

        # Q Learning: get maximum Q value at s' from target model
        target = rewards + (1 - dones) * self.discount_factor * next_pred.max(1)[0]
        target = Variable(target)

        errors = torch.abs(pred - target).data.numpy()

        # update priority
        for i in range(self.batch_size):
            idx = idxs[i]
            self.memory.update(idx, errors[i])

        self.optimizer.zero_grad()

        # MSE Loss function
        loss = (torch.FloatTensor(is_weights) * F.mse_loss(pred, target)).mean()
        loss.backward()

        # and train
        self.optimizer.step()

# %%
    # In case of CartPole-v1, maximum length of episode is 500
    env = gym.make('CartPole-v1')
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n
    model = DQN(state_size, action_size)

    agent = DQNAgent(state_size, action_size)
    scores, episodes = [], []
# Out:
# /home/inksci/miniconda3/envs/pytorch-tf-sns/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# /home/inksci/miniconda3/envs/pytorch-tf-sns/lib/python3.6/site-packages/ipykernel_launcher.py:45: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.

# %%
import os
dirs = ['./save_graph', './save_model']
for i_dir in dirs:
    if not os.path.exists(i_dir):
        os.makedirs(i_dir)

# %%
bool_break = 0
for e in range(EPISODES):
    done = False
    score = 0

    state = env.reset()
    state = np.reshape(state, [1, state_size])

    while not done:
        if agent.render:
            env.render()

        # get action for the current state and go one step in environment
        action = agent.get_action(state)

        next_state, reward, done, info = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        # if an action make the episode end, then gives penalty of -100
        reward = reward if not done or score == 499 else -10

        # save the sample <s, a, r, s'> to the replay memory
        agent.append_sample(state, action, reward, next_state, done)
        # every time step do the training
        if agent.memory.tree.n_entries >= agent.train_start:
            agent.train_model()

        score += reward
        state = next_state

        if done:
            # every episode update the target model to be same with model
            agent.update_target_model()

            # every episode, plot the play time
            score = score if score == 500 else score + 10
            scores.append(score)
            episodes.append(e)
            pylab.plot(episodes, scores, 'b')
            pylab.savefig("./save_graph/cartpole_dqn.png")
            print("episode:", e, "  score:", score, "  memory length:",
                  agent.memory.tree.n_entries, "  epsilon:", agent.epsilon)

            # if the mean of scores of last 10 episode is bigger than 490
            # stop training
            if np.mean(scores[-min(10, len(scores)):]) > 490:
                torch.save(agent.model, "./save_model/cartpole_dqn")
                # sys.exit()
                bool_break = 1
                break
    if bool_break:
        break
# Out:
# episode: 0   score: 16.0   memory length: 17   epsilon: 1.0
# episode: 1   score: 13.0   memory length: 31   epsilon: 1.0
# episode: 2   score: 17.0   memory length: 49   epsilon: 1.0
# episode: 3   score: 12.0   memory length: 62   epsilon: 1.0
# episode: 4   score: 23.0   memory length: 86   epsilon: 1.0
# episode: 5   score: 18.0   memory length: 105   epsilon: 1.0
# episode: 6   score: 22.0   memory length: 128   epsilon: 1.0
# episode: 7   score: 18.0   memory length: 147   epsilon: 1.0
# episode: 8   score: 38.0   memory length: 186   epsilon: 1.0
# episode: 9   score: 17.0   memory length: 204   epsilon: 1.0
# episode: 10   score: 9.0   memory length: 214   epsilon: 1.0
# episode: 11   score: 19.0   memory length: 234   epsilon: 1.0
# episode: 12   score: 22.0   memory length: 257   epsilon: 1.0
# episode: 13   score: 21.0   memory length: 279   epsilon: 1.0
# episode: 14   score: 20.0   memory length: 300   epsilon: 1.0
# episode: 15   score: 18.0   memory length: 319   epsilon: 1.0
# episode: 16   score: 13.0   memory length: 333   epsilon: 1.0
# episode: 17   score: 12.0   memory length: 346   epsilon: 1.0
# episode: 18   score: 16.0   memory length: 363   epsilon: 1.0
# episode: 19   score: 20.0   memory length: 384   epsilon: 1.0
# episode: 20   score: 9.0   memory length: 394   epsilon: 1.0
# episode: 21   score: 14.0   memory length: 409   epsilon: 1.0
# episode: 22   score: 28.0   memory length: 438   epsilon: 1.0
# episode: 23   score: 27.0   memory length: 466   epsilon: 1.0
# episode: 24   score: 11.0   memory length: 478   epsilon: 1.0
# episode: 25   score: 14.0   memory length: 493   epsilon: 1.0
# episode: 26   score: 33.0   memory length: 527   epsilon: 1.0
# episode: 27   score: 12.0   memory length: 540   epsilon: 1.0
# episode: 28   score: 36.0   memory length: 577   epsilon: 1.0
# episode: 29   score: 19.0   memory length: 597   epsilon: 1.0
# episode: 30   score: 27.0   memory length: 625   epsilon: 1.0
# episode: 31   score: 45.0   memory length: 671   epsilon: 1.0
# episode: 32   score: 13.0   memory length: 685   epsilon: 1.0
# episode: 33   score: 62.0   memory length: 748   epsilon: 1.0
# episode: 34   score: 9.0   memory length: 758   epsilon: 1.0
# episode: 35   score: 43.0   memory length: 802   epsilon: 1.0
# episode: 36   score: 10.0   memory length: 813   epsilon: 1.0
# episode: 37   score: 16.0   memory length: 830   epsilon: 1.0
# episode: 38   score: 13.0   memory length: 844   epsilon: 1.0
# episode: 39   score: 40.0   memory length: 885   epsilon: 1.0
# episode: 40   score: 18.0   memory length: 904   epsilon: 1.0
# episode: 41   score: 34.0   memory length: 939   epsilon: 1.0
# episode: 42   score: 22.0   memory length: 962   epsilon: 1.0
# episode: 43   score: 37.0   memory length: 1000   epsilon: 0.999802
# episode: 44   score: 13.0   memory length: 1014   epsilon: 0.9970299999999995
# episode: 45   score: 16.0   memory length: 1031   epsilon: 0.993663999999999
# episode: 46   score: 19.0   memory length: 1051   epsilon: 0.9897039999999984
# episode: 47   score: 14.0   memory length: 1066   epsilon: 0.9867339999999979
# episode: 48   score: 22.0   memory length: 1089   epsilon: 0.9821799999999972
# episode: 49   score: 29.0   memory length: 1119   epsilon: 0.9762399999999962
# episode: 50   score: 12.0   memory length: 1132   epsilon: 0.9736659999999958
# episode: 51   score: 28.0   memory length: 1161   epsilon: 0.9679239999999949
# episode: 52   score: 11.0   memory length: 1173   epsilon: 0.9655479999999945
# episode: 53   score: 29.0   memory length: 1203   epsilon: 0.9596079999999936
# episode: 54   score: 51.0   memory length: 1255   epsilon: 0.9493119999999919
# episode: 55   score: 31.0   memory length: 1287   epsilon: 0.9429759999999909
# episode: 56   score: 15.0   memory length: 1303   epsilon: 0.9398079999999904
# episode: 57   score: 44.0   memory length: 1348   epsilon: 0.930897999999989
# episode: 58   score: 40.0   memory length: 1389   epsilon: 0.9227799999999877
# episode: 59   score: 16.0   memory length: 1406   epsilon: 0.9194139999999872
# episode: 60   score: 39.0   memory length: 1446   epsilon: 0.9114939999999859
# episode: 61   score: 30.0   memory length: 1477   epsilon: 0.905355999999985
# episode: 62   score: 45.0   memory length: 1523   epsilon: 0.8962479999999835
# episode: 63   score: 25.0   memory length: 1549   epsilon: 0.8910999999999827
# episode: 64   score: 26.0   memory length: 1576   epsilon: 0.8857539999999818
# episode: 65   score: 48.0   memory length: 1625   epsilon: 0.8760519999999803
# episode: 66   score: 17.0   memory length: 1643   epsilon: 0.8724879999999797
# episode: 67   score: 49.0   memory length: 1693   epsilon: 0.8625879999999782
# episode: 68   score: 26.0   memory length: 1720   epsilon: 0.8572419999999773
# episode: 69   score: 22.0   memory length: 1743   epsilon: 0.8526879999999766
# episode: 70   score: 21.0   memory length: 1765   epsilon: 0.8483319999999759
# episode: 71   score: 17.0   memory length: 1783   epsilon: 0.8447679999999753
# episode: 72   score: 66.0   memory length: 1850   epsilon: 0.8315019999999732
# episode: 73   score: 36.0   memory length: 1887   epsilon: 0.824175999999972
# episode: 74   score: 19.0   memory length: 1907   epsilon: 0.8202159999999714
# episode: 75   score: 21.0   memory length: 1929   epsilon: 0.8158599999999707
# episode: 76   score: 27.0   memory length: 1957   epsilon: 0.8103159999999698
# episode: 77   score: 19.0   memory length: 1977   epsilon: 0.8063559999999692
# episode: 78   score: 71.0   memory length: 2049   epsilon: 0.7920999999999669
# episode: 79   score: 17.0   memory length: 2067   epsilon: 0.7885359999999664
# episode: 80   score: 37.0   memory length: 2105   epsilon: 0.7810119999999652
# episode: 81   score: 16.0   memory length: 2122   epsilon: 0.7776459999999646
# episode: 82   score: 31.0   memory length: 2154   epsilon: 0.7713099999999636
# episode: 83   score: 26.0   memory length: 2181   epsilon: 0.7659639999999628
# episode: 84   score: 14.0   memory length: 2196   epsilon: 0.7629939999999623
# episode: 85   score: 31.0   memory length: 2228   epsilon: 0.7566579999999613
# episode: 86   score: 52.0   memory length: 2281   epsilon: 0.7461639999999596
# episode: 87   score: 40.0   memory length: 2322   epsilon: 0.7380459999999583
# episode: 88   score: 12.0   memory length: 2335   epsilon: 0.7354719999999579
# episode: 89   score: 24.0   memory length: 2360   epsilon: 0.7305219999999572
# episode: 90   score: 60.0   memory length: 2421   epsilon: 0.7184439999999552
# episode: 91   score: 16.0   memory length: 2438   epsilon: 0.7150779999999547
# episode: 92   score: 101.0   memory length: 2540   epsilon: 0.6948819999999515
# episode: 93   score: 16.0   memory length: 2557   epsilon: 0.691515999999951
# episode: 94   score: 44.0   memory length: 2602   epsilon: 0.6826059999999495
# episode: 95   score: 69.0   memory length: 2672   epsilon: 0.6687459999999473
# episode: 96   score: 59.0   memory length: 2732   epsilon: 0.6568659999999454
# episode: 97   score: 91.0   memory length: 2824   epsilon: 0.6386499999999425
# episode: 98   score: 20.0   memory length: 2845   epsilon: 0.6344919999999419
# episode: 99   score: 30.0   memory length: 2876   epsilon: 0.6283539999999409
# episode: 100   score: 24.0   memory length: 2901   epsilon: 0.6234039999999401
# episode: 101   score: 43.0   memory length: 2945   epsilon: 0.6146919999999387
# episode: 102   score: 11.0   memory length: 2957   epsilon: 0.6123159999999384
# episode: 103   score: 122.0   memory length: 3080   epsilon: 0.5879619999999345
# episode: 104   score: 69.0   memory length: 3150   epsilon: 0.5741019999999323
# episode: 105   score: 20.0   memory length: 3171   epsilon: 0.5699439999999316
# episode: 106   score: 15.0   memory length: 3187   epsilon: 0.5667759999999311
# episode: 107   score: 67.0   memory length: 3255   epsilon: 0.553311999999929
# episode: 108   score: 90.0   memory length: 3346   epsilon: 0.5352939999999261
# episode: 109   score: 181.0   memory length: 3528   epsilon: 0.4992579999999206
# episode: 110   score: 119.0   memory length: 3648   epsilon: 0.4754979999999235
# episode: 111   score: 89.0   memory length: 3738   epsilon: 0.45767799999992564
# episode: 112   score: 23.0   memory length: 3762   epsilon: 0.4529259999999262
# episode: 113   score: 34.0   memory length: 3797   epsilon: 0.44599599999992706
# episode: 114   score: 103.0   memory length: 3901   epsilon: 0.42540399999992956
# episode: 115   score: 106.0   memory length: 4008   epsilon: 0.40421799999993213
# episode: 116   score: 128.0   memory length: 4137   epsilon: 0.37867599999993523
# episode: 117   score: 192.0   memory length: 4330   epsilon: 0.34046199999993987
# episode: 118   score: 116.0   memory length: 4447   epsilon: 0.3172959999999427
# episode: 119   score: 92.0   memory length: 4540   epsilon: 0.2988819999999449
# episode: 120   score: 132.0   memory length: 4673   epsilon: 0.2725479999999481
# episode: 121   score: 94.0   memory length: 4768   epsilon: 0.2537379999999504
# episode: 122   score: 143.0   memory length: 4912   epsilon: 0.22522599999995035
# episode: 123   score: 117.0   memory length: 5030   epsilon: 0.20186199999994991
# episode: 124   score: 116.0   memory length: 5147   epsilon: 0.17869599999994948
# episode: 125   score: 160.0   memory length: 5308   epsilon: 0.14681799999994888
# episode: 126   score: 120.0   memory length: 5429   epsilon: 0.12285999999994843
# episode: 127   score: 132.0   memory length: 5562   epsilon: 0.09652599999994793
# episode: 128   score: 148.0   memory length: 5711   epsilon: 0.06702399999994738
# episode: 129   score: 178.0   memory length: 5890   epsilon: 0.0315819999999478
# episode: 130   score: 115.0   memory length: 6006   epsilon: 0.009999999999947773
# episode: 131   score: 144.0   memory length: 6151   epsilon: 0.009999999999947773
# episode: 132   score: 138.0   memory length: 6290   epsilon: 0.009999999999947773
# episode: 133   score: 150.0   memory length: 6441   epsilon: 0.009999999999947773
# episode: 134   score: 162.0   memory length: 6604   epsilon: 0.009999999999947773
# episode: 135   score: 139.0   memory length: 6744   epsilon: 0.009999999999947773
# episode: 136   score: 154.0   memory length: 6899   epsilon: 0.009999999999947773
# episode: 137   score: 165.0   memory length: 7065   epsilon: 0.009999999999947773
# episode: 138   score: 290.0   memory length: 7356   epsilon: 0.009999999999947773
# episode: 139   score: 192.0   memory length: 7549   epsilon: 0.009999999999947773
# episode: 140   score: 154.0   memory length: 7704   epsilon: 0.009999999999947773
# episode: 141   score: 177.0   memory length: 7882   epsilon: 0.009999999999947773
# episode: 142   score: 185.0   memory length: 8068   epsilon: 0.009999999999947773
# episode: 143   score: 163.0   memory length: 8232   epsilon: 0.009999999999947773
# episode: 144   score: 201.0   memory length: 8434   epsilon: 0.009999999999947773
# episode: 145   score: 161.0   memory length: 8596   epsilon: 0.009999999999947773
# episode: 146   score: 149.0   memory length: 8746   epsilon: 0.009999999999947773
# episode: 147   score: 207.0   memory length: 8954   epsilon: 0.009999999999947773
# episode: 148   score: 158.0   memory length: 9113   epsilon: 0.009999999999947773
# episode: 149   score: 197.0   memory length: 9311   epsilon: 0.009999999999947773
# episode: 150   score: 177.0   memory length: 9489   epsilon: 0.009999999999947773
# episode: 151   score: 210.0   memory length: 9700   epsilon: 0.009999999999947773
# episode: 152   score: 197.0   memory length: 9898   epsilon: 0.009999999999947773
# episode: 153   score: 170.0   memory length: 10069   epsilon: 0.009999999999947773
# episode: 154   score: 402.0   memory length: 10472   epsilon: 0.009999999999947773
# episode: 155   score: 164.0   memory length: 10637   epsilon: 0.009999999999947773
# episode: 156   score: 200.0   memory length: 10838   epsilon: 0.009999999999947773
# episode: 157   score: 212.0   memory length: 11051   epsilon: 0.009999999999947773
# episode: 158   score: 210.0   memory length: 11262   epsilon: 0.009999999999947773
# episode: 159   score: 221.0   memory length: 11484   epsilon: 0.009999999999947773
# episode: 160   score: 219.0   memory length: 11704   epsilon: 0.009999999999947773
# episode: 161   score: 334.0   memory length: 12039   epsilon: 0.009999999999947773
# episode: 162   score: 186.0   memory length: 12226   epsilon: 0.009999999999947773
# episode: 163   score: 224.0   memory length: 12451   epsilon: 0.009999999999947773
# episode: 164   score: 206.0   memory length: 12658   epsilon: 0.009999999999947773
# episode: 165   score: 188.0   memory length: 12847   epsilon: 0.009999999999947773
# episode: 166   score: 153.0   memory length: 13001   epsilon: 0.009999999999947773
# episode: 167   score: 143.0   memory length: 13145   epsilon: 0.009999999999947773
# episode: 168   score: 307.0   memory length: 13453   epsilon: 0.009999999999947773
# episode: 169   score: 320.0   memory length: 13774   epsilon: 0.009999999999947773
# episode: 170   score: 177.0   memory length: 13952   epsilon: 0.009999999999947773
# episode: 171   score: 221.0   memory length: 14174   epsilon: 0.009999999999947773
# episode: 172   score: 174.0   memory length: 14349   epsilon: 0.009999999999947773
# episode: 173   score: 220.0   memory length: 14570   epsilon: 0.009999999999947773
# episode: 174   score: 211.0   memory length: 14782   epsilon: 0.009999999999947773
# episode: 175   score: 149.0   memory length: 14932   epsilon: 0.009999999999947773
# episode: 176   score: 213.0   memory length: 15146   epsilon: 0.009999999999947773
# episode: 177   score: 182.0   memory length: 15329   epsilon: 0.009999999999947773
# episode: 178   score: 222.0   memory length: 15552   epsilon: 0.009999999999947773
# episode: 179   score: 170.0   memory length: 15723   epsilon: 0.009999999999947773
# episode: 180   score: 144.0   memory length: 15868   epsilon: 0.009999999999947773
# episode: 181   score: 265.0   memory length: 16134   epsilon: 0.009999999999947773
# episode: 182   score: 218.0   memory length: 16353   epsilon: 0.009999999999947773
# episode: 183   score: 180.0   memory length: 16534   epsilon: 0.009999999999947773
# episode: 184   score: 157.0   memory length: 16692   epsilon: 0.009999999999947773
# episode: 185   score: 133.0   memory length: 16826   epsilon: 0.009999999999947773
# episode: 186   score: 214.0   memory length: 17041   epsilon: 0.009999999999947773
# episode: 187   score: 200.0   memory length: 17242   epsilon: 0.009999999999947773
# episode: 188   score: 144.0   memory length: 17387   epsilon: 0.009999999999947773
# episode: 189   score: 151.0   memory length: 17539   epsilon: 0.009999999999947773
# episode: 190   score: 133.0   memory length: 17673   epsilon: 0.009999999999947773
# episode: 191   score: 132.0   memory length: 17806   epsilon: 0.009999999999947773
# episode: 192   score: 104.0   memory length: 17911   epsilon: 0.009999999999947773
# episode: 193   score: 104.0   memory length: 18016   epsilon: 0.009999999999947773
# episode: 194   score: 152.0   memory length: 18169   epsilon: 0.009999999999947773
# episode: 195   score: 149.0   memory length: 18319   epsilon: 0.009999999999947773
# episode: 196   score: 102.0   memory length: 18422   epsilon: 0.009999999999947773
# episode: 197   score: 194.0   memory length: 18617   epsilon: 0.009999999999947773
# episode: 198   score: 157.0   memory length: 18775   epsilon: 0.009999999999947773
# episode: 199   score: 230.0   memory length: 19006   epsilon: 0.009999999999947773
# episode: 200   score: 124.0   memory length: 19131   epsilon: 0.009999999999947773
# episode: 201   score: 100.0   memory length: 19232   epsilon: 0.009999999999947773
# episode: 202   score: 98.0   memory length: 19331   epsilon: 0.009999999999947773
# episode: 203   score: 101.0   memory length: 19433   epsilon: 0.009999999999947773
# episode: 204   score: 159.0   memory length: 19593   epsilon: 0.009999999999947773
# episode: 205   score: 175.0   memory length: 19769   epsilon: 0.009999999999947773
# episode: 206   score: 97.0   memory length: 19867   epsilon: 0.009999999999947773
# episode: 207   score: 140.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 208   score: 131.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 209   score: 144.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 210   score: 127.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 211   score: 195.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 212   score: 169.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 213   score: 168.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 214   score: 180.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 215   score: 128.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 216   score: 123.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 217   score: 177.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 218   score: 129.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 219   score: 123.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 220   score: 163.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 221   score: 168.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 222   score: 158.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 223   score: 186.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 224   score: 156.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 225   score: 141.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 226   score: 160.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 227   score: 172.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 228   score: 173.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 229   score: 184.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 230   score: 220.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 231   score: 412.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 232   score: 221.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 233   score: 190.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 234   score: 208.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 235   score: 139.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 236   score: 150.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 237   score: 168.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 238   score: 161.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 239   score: 160.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 240   score: 145.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 241   score: 139.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 242   score: 147.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 243   score: 137.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 244   score: 147.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 245   score: 136.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 246   score: 146.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 247   score: 153.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 248   score: 150.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 249   score: 147.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 250   score: 145.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 251   score: 161.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 252   score: 139.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 253   score: 134.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 254   score: 132.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 255   score: 10.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 256   score: 10.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 257   score: 10.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 258   score: 9.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 259   score: 10.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 260   score: 129.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 261   score: 10.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 262   score: 138.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 263   score: 149.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 264   score: 146.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 265   score: 164.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 266   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 267   score: 216.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 268   score: 233.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 269   score: 285.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 270   score: 308.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 271   score: 370.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 272   score: 294.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 273   score: 318.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 274   score: 184.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 275   score: 245.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 276   score: 204.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 277   score: 258.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 278   score: 187.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 279   score: 163.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 280   score: 212.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 281   score: 283.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 282   score: 220.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 283   score: 161.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 284   score: 418.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 285   score: 360.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 286   score: 203.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 287   score: 148.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 288   score: 144.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 289   score: 180.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 290   score: 176.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 291   score: 430.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 292   score: 186.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 293   score: 164.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 294   score: 253.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 295   score: 172.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 296   score: 157.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 297   score: 155.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 298   score: 139.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 299   score: 154.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 300   score: 174.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 301   score: 149.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 302   score: 213.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 303   score: 396.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 304   score: 359.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 305   score: 206.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 306   score: 162.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 307   score: 160.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 308   score: 166.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 309   score: 158.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 310   score: 165.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 311   score: 158.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 312   score: 177.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 313   score: 150.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 314   score: 198.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 315   score: 168.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 316   score: 195.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 317   score: 167.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 318   score: 144.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 319   score: 160.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 320   score: 318.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 321   score: 133.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 322   score: 187.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 323   score: 130.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 324   score: 159.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 325   score: 224.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 326   score: 207.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 327   score: 160.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 328   score: 239.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 329   score: 233.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 330   score: 243.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 331   score: 175.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 332   score: 159.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 333   score: 180.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 334   score: 153.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 335   score: 150.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 336   score: 153.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 337   score: 192.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 338   score: 204.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 339   score: 175.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 340   score: 156.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 341   score: 127.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 342   score: 141.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 343   score: 143.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 344   score: 140.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 345   score: 138.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 346   score: 183.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 347   score: 142.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 348   score: 128.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 349   score: 139.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 350   score: 142.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 351   score: 145.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 352   score: 139.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 353   score: 129.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 354   score: 143.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 355   score: 127.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 356   score: 132.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 357   score: 131.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 358   score: 148.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 359   score: 137.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 360   score: 130.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 361   score: 134.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 362   score: 143.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 363   score: 141.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 364   score: 150.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 365   score: 137.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 366   score: 162.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 367   score: 146.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 368   score: 162.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 369   score: 152.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 370   score: 163.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 371   score: 169.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 372   score: 203.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 373   score: 148.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 374   score: 152.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 375   score: 158.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 376   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 377   score: 204.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 378   score: 176.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 379   score: 322.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 380   score: 127.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 381   score: 363.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 382   score: 282.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 383   score: 274.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 384   score: 246.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 385   score: 203.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 386   score: 187.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 387   score: 17.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 388   score: 21.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 389   score: 17.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 390   score: 19.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 391   score: 16.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 392   score: 14.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 393   score: 16.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 394   score: 24.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 395   score: 18.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 396   score: 14.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 397   score: 17.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 398   score: 14.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 399   score: 13.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 400   score: 14.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 401   score: 19.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 402   score: 14.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 403   score: 17.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 404   score: 14.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 405   score: 13.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 406   score: 15.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 407   score: 18.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 408   score: 16.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 409   score: 12.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 410   score: 15.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 411   score: 15.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 412   score: 17.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 413   score: 14.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 414   score: 17.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 415   score: 26.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 416   score: 39.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 417   score: 18.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 418   score: 131.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 419   score: 124.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 420   score: 141.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 421   score: 144.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 422   score: 164.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 423   score: 152.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 424   score: 160.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 425   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 426   score: 272.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 427   score: 179.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 428   score: 156.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 429   score: 186.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 430   score: 174.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 431   score: 248.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 432   score: 154.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 433   score: 153.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 434   score: 153.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 435   score: 139.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 436   score: 152.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 437   score: 151.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 438   score: 174.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 439   score: 167.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 440   score: 138.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 441   score: 158.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 442   score: 158.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 443   score: 145.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 444   score: 156.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 445   score: 149.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 446   score: 140.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 447   score: 138.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 448   score: 175.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 449   score: 139.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 450   score: 143.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 451   score: 145.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 452   score: 190.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 453   score: 173.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 454   score: 174.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 455   score: 191.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 456   score: 161.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 457   score: 151.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 458   score: 140.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 459   score: 202.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 460   score: 171.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 461   score: 228.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 462   score: 166.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 463   score: 257.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 464   score: 226.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 465   score: 240.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 466   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 467   score: 246.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 468   score: 194.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 469   score: 243.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 470   score: 298.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 471   score: 274.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 472   score: 195.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 473   score: 202.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 474   score: 193.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 475   score: 250.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 476   score: 263.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 477   score: 270.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 478   score: 232.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 479   score: 193.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 480   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 481   score: 345.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 482   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 483   score: 199.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 484   score: 203.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 485   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 486   score: 276.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 487   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 488   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 489   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 490   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 491   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 492   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 493   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 494   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 495   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 496   score: 257.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 497   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 498   score: 500.0   memory length: 20000   epsilon: 0.009999999999947773
# episode: 499   score: 204.0   memory length: 20000   epsilon: 0.009999999999947773
